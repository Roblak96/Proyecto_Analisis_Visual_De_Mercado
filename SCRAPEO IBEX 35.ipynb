# %%
import requests
import pandas as pd
from datetime import date
from datetime import datetime
import datetime
import time
import urllib
from bs4 import BeautifulSoup
import re
from urllib.request import urlopen
import lxml.html as lh

# %%
url = 'https://www.bolsamadrid.es/esp/aspx/Mercados/Precios.aspx?indice=ESI100000000&punto=indice'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
[len(T) for T in tr_elements[8:44]]
# Out:
# [9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9]

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[8]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Nombre"
# 2:"Últ."
# 3:"% Dif."
# 4:"Máx."
# 5:"Mín."
# 6:"Volumen"
# 7:"Efectivo (miles €)"
# 8:"Fecha"
# 9:"Hora"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(8,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=9:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [36, 36, 36, 36, 36, 36, 36, 36, 36]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df
# Out:
#           Nombre      Últ.  % Dif.      Máx.      Mín.     Volumen  \
# 0         Nombre      Últ.  % Dif.      Máx.      Mín.     Volumen
# 1        ACCIONA  161,3000    1,32  161,3000  159,2000      12.061
# 2       ACERINOX   10,8400    2,60   10,8850   10,7200     212.741
# 3            ACS   21,5700    2,08   21,6000   21,4000     123.207
# 4           AENA  130,2500    1,05  130,9500  129,2500      23.239
# 5       ALMIRALL   11,0000    1,29   11,0200   10,8900      84.092
# 6        AMADEUS   55,1600    1,25   55,8400   54,8400     255.033
# 7    ARCELORMIT.   28,4350    3,63   28,4900   27,9500     306.110
# 8    B.SANTANDER    2,7200    2,39    2,7240    2,6785   9.404.119
# 9    BA.SABADELL    0,5854    0,76    0,5918    0,5824   5.418.501
# 10     BANKINTER    4,4380    1,12    4,4500    4,4140     332.769
# 11          BBVA    5,1520    1,14    5,1930    5,1260   3.685.526
# 12     CAIXABANK    2,3250    1,66    2,3320    2,3140   1.300.888
# 13       CELLNEX   52,5200    0,54   53,3600   52,4400      93.240
# 14  CIE AUTOMOT.   26,6000    1,76   26,9000   26,3600      23.667
# 15        ENAGAS   20,9100    0,53   20,9500   20,7600     290.587
# 16        ENDESA   19,8950    0,20   20,0500   19,8000     221.411
# 17     FERROVIAL   25,7200    1,66   25,7700   25,4500     515.739
# 18       FLUIDRA   33,2000    2,63   33,2500   32,7000     148.343
# 19  GRIFOLS CL.A   16,2450    2,11   16,2500   15,8900     278.923
# 20           IAG    1,5215    2,42    1,5340    1,4850  10.034.656
# 21     IBERDROLA    9,9040    1,25    9,9180    9,8100   1.823.761
# 22       INDITEX   28,0500    2,26   28,1900   27,7300     701.099
# 23       INDRA A    9,2450   -1,07    9,5900    9,2200     516.653
# 24  INM.COLONIAL    7,9500    0,32    8,0250    7,9350      64.350
