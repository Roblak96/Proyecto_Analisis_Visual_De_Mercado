# %%
import requests
import pandas as pd
from datetime import date
from datetime import datetime
import datetime
import time
import urllib
from bs4 import BeautifulSoup
import re
from urllib.request import urlopen
import lxml.html as lh

# %%
url = 'https://www.bolsamadrid.es/esp/aspx/Mercados/Precios.aspx?indice=ESI100000000&punto=indice'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
[len(T) for T in tr_elements[8:44]]
# Out:
# [9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9]

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[8]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"Nombre"
# 2:"Últ."
# 3:"% Dif."
# 4:"Máx."
# 5:"Mín."
# 6:"Volumen"
# 7:"Efectivo (miles €)"
# 8:"Fecha"
# 9:"Hora"

# %%
#Since out first row is the header, data is stored on the second row onwards
for j in range(8,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    #If row is not of size 10, the //tr data is not from our table 
    if len(T)!=9:
        break
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
[len(C) for (title,C) in col]
# Out:
# [36, 36, 36, 36, 36, 36, 36, 36, 36]

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
df
# Out:
#           Nombre      Últ.  % Dif.      Máx.      Mín.    Volumen  \
# 0         Nombre      Últ.  % Dif.      Máx.      Mín.    Volumen
# 1        ACCIONA  159,6000   -0,13  160,3000  158,0000      4.165
# 2       ACERINOX   10,2200    0,15   10,2500   10,1650    117.038
# 3            ACS   21,4900    0,37   21,5900   21,3000     40.830
# 4           AENA  130,1500   -0,38  130,6000  129,0500      9.978
# 5       ALMIRALL   10,6800   -0,19   10,7400   10,6300     68.359
# 6        AMADEUS   57,4800   -0,24   57,6600   56,5800     73.942
# 7    ARCELORMIT.   25,9950    0,81   26,0950   25,8000     54.505
# 8    B.SANTANDER    2,7215    0,15    2,7250    2,7000  5.875.341
# 9    BA.SABADELL    0,5942   -0,47    0,5978    0,5900  1.702.797
# 10     BANKINTER    4,3380   -0,12    4,3540    4,3290     80.755
# 11          BBVA    5,1020   -1,03    5,1240    5,0410  2.697.515
# 12     CAIXABANK    2,3090   -0,69    2,3270    2,3040  1.154.458
# 13       CELLNEX   51,8600   -1,33   52,1600   51,7200     52.285
# 14  CIE AUTOMOT.   26,6200   -0,15   26,6800   26,3800     23.607
# 15        ENAGAS   20,5600   -0,05   20,5900   20,4600     81.645
# 16        ENDESA   19,7250   -0,20   19,7950   19,6650     41.152
# 17     FERROVIAL   25,7100   -0,04   25,7900   25,5600     40.775
# 18       FLUIDRA   33,1500   -1,63   33,6000   33,0500     27.952
# 19  GRIFOLS CL.A   15,4100    0,10   15,6300   15,3550    123.280
# 20           IAG    1,6130    0,31    1,6240    1,5920  1.750.479
# 21     IBERDROLA    9,7780   -0,89    9,8720    9,7580    769.529
# 22       INDITEX   28,5700    1,03   28,6400   28,3100    239.745
# 23       INDRA A   10,4100   -0,67   10,5000   10,3800     93.755
# 24  INM.COLONIAL    8,0200    0,69    8,0500    7,8850     62.089
