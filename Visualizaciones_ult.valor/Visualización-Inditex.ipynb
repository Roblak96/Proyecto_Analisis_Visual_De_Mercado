# %%
import csv
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
# %matplotlib inline
# %config Inlinebackend.figure_format= 'retina'

# %%
sns.set_context("poster")
sns.set(rc={"figure.figsize": (20.,8.)})
sns.set_style("whitegrid")

# %%
df2 = pd.read_csv('data/Inditex.csv')
df2
# Out:
#           Fecha  Último Apertura  Máximo  Mínimo   Vol.  % var.
# 0    10.12.2021  28,400   28,390  28,800  28,210  2,45M   0,42%
# 1    09.12.2021  28,280   28,700  28,790  28,210  3,19M  -1,81%
# 2    08.12.2021  28,800   29,720  29,890  28,720  5,03M  -2,90%
# 3    07.12.2021  29,660   28,990  29,660  28,690  4,06M   3,63%
# 4    06.12.2021  28,620   28,160  28,620  27,940  2,96M   2,76%
# ..          ...     ...      ...     ...     ...    ...     ...
# 238  08.01.2021  26,720   26,500  26,720  26,340  2,33M   1,87%
# 239  07.01.2021  26,230   26,570  26,570  25,930  2,54M  -0,64%
# 240  06.01.2021  26,400   25,920  26,480  25,530  2,45M   2,52%
# 241  05.01.2021  25,750   25,700  25,970  25,510  1,85M  -0,35%
# 242  04.01.2021  25,840   26,430  26,430  25,710  8,75M  -0,77%
#
# [243 rows x 7 columns]

# %%
df2["Último"] = df2["Último"].str.replace(",", ".")
df2["Apertura"] = df2["Apertura"].str.replace(",", ".")
df2["Máximo"] = df2["Máximo"].str.replace(",", ".")
df2["Mínimo"] = df2["Mínimo"].str.replace(",", ".")
df2["Vol."] = df2["Vol."].str.replace(",", ".")
df2["% var."] = df2["% var."].str.replace(",", ".")

# %%
df2 = df2.astype({"Último" : "float"})

# %%
df2 = df2.astype({"Apertura" : "float"})

# %%
df2 = df2.astype({"Máximo" : "float"})

# %%
df2 = df2.astype({"Mínimo" : "float"})

# %%
def astype_vol(x):
    try:
        return float(x) 
    except: 
        return np.nan

# %%
df2.head()
# Out:
#         Fecha  Último  Apertura  Máximo  Mínimo   Vol.  % var.
# 0  10.12.2021   28.40     28.39   28.80   28.21  2.45M   0.42%
# 1  09.12.2021   28.28     28.70   28.79   28.21  3.19M  -1.81%
# 2  08.12.2021   28.80     29.72   29.89   28.72  5.03M  -2.90%
# 3  07.12.2021   29.66     28.99   29.66   28.69  4.06M   3.63%
# 4  06.12.2021   28.62     28.16   28.62   27.94  2.96M   2.76%

# %%
df2["Vol."] = df2["Vol."].str.replace("K","")
df2["% var."] = df2["% var."].str.replace("%","")

# %%
df2["Vol."] = df2["Vol."].apply(astype_vol)

# %%
df2["% var."] = df2["% var."].apply(astype_vol)

# %%
df2['date'] = pd.to_datetime(df2['Fecha']).dt.date

# %%
df2[["Fecha2"]] = df2[["Fecha"]].apply(pd.to_datetime)# ME DESCUADRA LA TABLA

# %%
df2.dtypes
# Out:
# Fecha               object
# Último             float64
# Apertura           float64
# Máximo             float64
# Mínimo             float64
# Vol.               float64
# % var.             float64
# date                object
# Fecha2      datetime64[ns]
# dtype: object

# %%
df2.head(2)
# Out:
#         Fecha  Último  Apertura  Máximo  Mínimo  Vol.  % var.        date  \
# 0  10.12.2021   28.40     28.39   28.80   28.21   NaN    0.42  2021-10-12
# 1  09.12.2021   28.28     28.70   28.79   28.21   NaN   -1.81  2021-09-12
#
#       Fecha2
# 0 2021-10-12
# 1 2021-09-12

# %%
#df2.yea

# %%
def month(x):
    return x.split('.')[1]
def year(x):
    return x.split('.')[2]

# %%
df2['month'] = df2['Fecha'].apply(month)
df2['year'] = df2['Fecha'].apply(year)

# %%
empresax = pd.DataFrame(df2.groupby(["year", "month"])["Apertura"].mean()).reset_index()

# %%
empresax.head()
# Out:
#    year month   Apertura
# 0  2021    01  25.868500
# 1  2021    02  25.912000
# 2  2021    03  28.413043
# 3  2021    04  28.522000
# 4  2021    05  31.355238

# %%
sns.lineplot(data = empresax, x = "month", y = "Apertura");

# %%
sns.lineplot(data = df2, x = "Fecha", y = "Último");

# %%
#Selector de archivos csv y filtrado por columnas

# %%
with open('data/Acciona.csv') as csvarchivo:
    entrada = csv.DictReader(csvarchivo)
    for reg in entrada:
        print(reg['Último'])
# Out:
# 158,600
# 159,800
# 159,100
# 161,800
# 158,300
# 155,200
# 155,200
# 159,500
# 157,500
# 159,000
# 159,300
# 163,000
# 160,900
# 159,400
# 160,400
# 158,800
# 158,400
# 160,900
# 162,000
# 161,500
# 159,500
# 159,100
# 159,700
# 157,200
# 157,700
# 157,000
# 159,100
# 159,500
# 166,900
# 166,000
# 165,800
# 167,100
# 164,400
# 163,200
# 162,600
# 161,100
# 157,800
# 156,000
# 151,500
# 148,700
# 151,200
# 148,300
# 147,300
# 145,300
# 142,500
# 144,100
# 143,400
# 140,900
# 142,200
# 142,200
# 143,900
# 143,200
# 144,500
# 143,300
# 149,000
# 147,200
# 145,700
# 144,600
# 145,000
# 139,900
# 144,100
# 141,000
# 146,000
# 148,000
# 148,100
# 143,700
# 143,400
# 141,200
# 140,000
# 141,000
# 141,600
# 142,200
# 139,800
# 137,600
# 137,900
# 137,000
# 136,900
# 140,100
# 140,700
# 140,600
# 139,800
# 139,500
# 141,000
# 138,300
# 138,000
# 137,700
# 137,200
# 135,800
# 135,300
# 133,200
# 130,400
# 131,500
# 130,500
# 128,100
# 129,700
# 129,200
# 133,100
# 131,800
# 130,500
# 131,800
# 131,500
# 129,500
# 128,300
# 125,800
# 125,000
# 127,000
# 125,700
# 127,300
# 128,600
# 128,100
# 127,200
# 124,900
# 127,600
# 124,800
# 124,300
# 128,800
# 129,400
# 127,300
# 127,900
# 127,200
# 126,700
# 127,000
# 125,200
# 126,800
# 127,400
# 128,400
# 137,900
# 138,600
# 136,000
# 135,700
# 131,300
# 132,000
# 134,800
# 140,900
# 137,000
# 134,400
# 133,800
# 134,700
# 137,700
# 138,100
# 141,900
# 141,600
# 140,900
# 139,700
# 138,600
# 139,000
# 137,600
# 136,000
# 136,400
# 135,300
# 135,400
# 131,600
# 131,600
# 134,100
# 138,800
# 139,600
# 136,400
# 139,500
# 138,100
# 145,600
# 144,700
# 145,300
# 145,100
# 146,200
# 144,500
# 144,600
# 143,000
# 138,700
# 139,800
# 140,200
# 140,500
# 138,600
# 138,400
# 140,700
# 141,100
# 140,000
# 140,800
# 138,200
# 137,100
# 144,100
# 142,900
# 142,400
# 140,800
# 140,700
# 139,200
# 138,200
# 138,000
# 137,100
# 135,200
# 134,200
# 135,300
# 136,000
# 136,300
# 131,100
# 132,500
# 129,400
# 129,400
# 125,000
# 126,000
# 126,200
# 127,100
# 133,100
# 135,000
# 133,400
# 134,200
# 134,400
# 133,600
# 136,500
# 144,200
# 138,400
# 124,200
# 125,200
# 123,700
# 122,900
# 124,800
# 124,100
# 125,600
# 130,000
# 129,000
# 127,000
# 127,600
# 126,500
# 125,100
# 123,700
# 126,600
# 123,000
# 132,600
# 129,000
# 128,800
# 128,800
# 128,700
# 128,900
# 127,100
# 125,700
# 126,900
# 126,700
# 125,300
# 124,600
# 127,900
# 126,100
# 119,500
# 116,500
# 117,100

# %%
df = pd.read_csv("data/Acciona.csv", sep=";")


# Cambiando el tipo de dato en fecha
df["Fecha"] = pd.to_datetime(df["Fecha"],format='%Y-%m-%d')



# Creando función
def funcion_graficar(valor):

    #Filtrando el pais
    df_filtrado = df[df["Último"] == valor]
    
    
    if df_filtrado.shape[0] == 0:
        print("Empresa no encontrada!!")
    else:
    # Graficando
        df_filtrado.plot(x ='Fecha', y='Últ.Valor', kind = 'bar')

# Corriendo función que genera la gráfica

pais = input("Ingrese la empresa: ")
funcion_graficar(valor)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fecha'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-b8a7becf0133> in <module>
#       3
#       4 # Cambiando el tipo de dato en fecha
# ----> 5 df["Fecha"] = pd.to_datetime(df["Fecha"],format='%Y-%m-%d')
#       6
#       7
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Fecha'
